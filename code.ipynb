# %%
# !pip install ultralytics
# Out:
# ...
# WARNING: You are using pip version 21.2.4; however, version 24.2 is available.
# You should consider upgrading via the 'C:\Users\rohan\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
from ultralytics import YOLO
model = YOLO('YOLO11n-pose.pt')
# Out:
# WARNING  imgsz=[328] must be multiple of max stride 32, updating to [352]
# image 1/1 d:\reasearch\Pose estimation\bus.jpg: 256x352 7 persons, 51.6ms
# Speed: 0.0ms preprocess, 51.6ms inference, 2.0ms postprocess per image at shape (1, 3, 256, 352)
# Results saved to runs\pose\predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'person'}
#  obb: None
#  orig_img: array([[[202, 165, 113],
#          [202, 165, 113],
#          [201, 164, 112],
#          ...,
#          [182, 149, 100],
#          [181, 148,  99],
#          [181, 148,  99]],
#
#         [[202, 165, 113],
#          [202, 165, 113],
#          [201, 164, 112],
#          ...,
#          [182, 149, 100],
#          [181, 148,  99],
#          [181, 148,  99]],
#
#         [[202, 165, 113],
#          [202, 165, 113],
#          [201, 164, 112],
#          ...,
# ...

# %%
#video pose etimation
source = "bus.jpg" 
model.predict(source, save= True, imgsz=328, conf=0.5)

# %%
#video pose etimation
source = "video.mp4" 
model.predict(source, save= True, imgsz=328, conf=0.5)
# Out:
# WARNING  imgsz=[328] must be multiple of max stride 32, updating to [352]
#
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/282) d:\reasearch\Pose estimation\video.mp4: 224x352 (no detections), 35.0ms
# video 1/1 (frame 2/282) d:\reasearch\Pose estimation\video.mp4: 224x352 (no detections), 30.5ms
# video 1/1 (frame 3/282) d:\reasearch\Pose estimation\video.mp4: 224x352 (no detections), 35.0ms
# ...

# %%
# !pip install opencv-python #install cv2

# %%
#webcam pose etimation

import cv2 
from ultralytics import YOLO
#Load the YOLOv11 model
model = YOLO('YOLO11n-pose.pt')
# Open the video file #
video_path = "path/to/your/video/file.mp4" 
video_path = 0 
cap = cv2.VideoCapture (video_path)
#Loop through the video frames 
while cap.isOpened(): # Read a frame from the video 
    success, frame = cap.read()
    if success:
# Run YOLOv11 inference on the frame 
        results = model (frame, save=True)
# Visualize the results on the frame 
        annotated_frame = results[0].plot()
# Display the annotated frame 
        cv2.imshow("YOLOv11 Inference", annotated_frame)
# Break the loop if 'q' is pressed 
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        break
# Release the video capture object and close the display window 
cap.release() 
cv2.destroyAllWindows()
# Out:
# WARNING  Python>=3.10 is required, but Python==3.9.10 is currently installed
#
# 0: 480x640 1 person, 98.9ms
# Speed: 3.0ms preprocess, 98.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict3
#
# 0: 480x640 1 person, 99.5ms
# Speed: 2.0ms preprocess, 99.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict3
#
# 0: 480x640 1 person, 93.5ms
# Speed: 4.0ms preprocess, 93.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict3
#
# 0: 480x640 1 person, 99.5ms
# Speed: 2.0ms preprocess, 99.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict3
#
# 0: 480x640 1 person, 121.5ms
# Speed: 2.0ms preprocess, 121.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\pose\predict3
#
# 0: 480x640 1 person, 76.5ms
# ...
